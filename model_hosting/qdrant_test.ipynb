# %%
# !python data_loader/qdrant_loader.py
# Out:
# c:\SKN AI CAMP TEAM\SKN09-FINAL-1Team\model_hosting\data_loader\qdrant_loader.py:31: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(

# %%
from data_loader.qdrant_loader import load_qdrant_db

# %%
# qdrant db 생성
result = load_qdrant_db("초거대 AI기반 플랫폼 이용지원사업 모집 공고")

print(result)
# Out:
# '초거대 AI기반 플랫폼 이용지원사업 모집 공고'에 대한 관련 문서 검색 결과:
#
# - 관련 문서 1:
# source: 2025 AI 영상 콘텐츠 스타트업 프로젝트 제작지원 모집공고.pdf
# category: 사업
# page: 1
# text: 2025 AI 영상 콘텐츠 스타트업 프로젝트 제작지원
# 모집 공고
# (재)부산정보산업진흥원은 AI기반 영상분야 제작 활성화 및 우수과제 발굴을 위하
# 여 「2025 AI 영상 콘텐츠 스타트업 프로젝트 제작지원」사업을 추진하오니 많은
# 관심과 참여를 부탁드립니다.
# 2025. 04.
# 1. 사업목적
# ▢ 부산 스타트업 기업의 콘텐츠 제작 활성화 및 우수과제 발굴
# ▢ AI를 활용한 신기술 기반 영상 콘텐츠 스타트업 초기 제작 지원
# 2. 지원내용 : AI를 활용한 영상 콘텐츠 스타트업 제작 지원
# ▢ 개발기간 : 협약체결일 ∼ 2025. 10. 31.
# ▢ 지원규모 : 창업 5년 미만 콘텐츠 스타트업 6개사(기업당 40,000,000원)
# ※ 지원금은 수행기업의 평가/점검 결과 및 정부/지차체 상황에 따라 변동 가능
# ※ 기업부담금 : 총사업비(지원금+자부담)의 10% 이상 (현금) 매칭 필수
# ※ 부산시 부산진구 소재 부산콘텐츠비즈타운 입주기업은 가산점 부여(2점) / 서류평가 한정
# 3. 지원분야
# ▢ 지원분야 : AI기반 영상(애니메이션, 실감미디어 등) 콘텐츠 분야
# 4. 신청자격 및 지원조건
# ▢ 신청자격 : 부산광역시에 위치한 창업 5년 미만 콘텐츠 기업
# ㅇ 공고 시작일 기준 6개월 이전에 부산 지역에 본사 또는 지사 설립
# ㅇ 비영리기업은 정부지원금은 지원하지 않으며, 자부담 최소 총사업비의 10% 매칭
# ㅇ 문화산업진흥기본법 제2조 참고 콘텐츠 산업분야에 해당되는 기업
# ㅇ 2025년도 콘텐츠 개발지원사업 공모 중복선정 불가 (타지역 포함)
# ㅇ 진행률 30%이상 진행 프로젝트 우선지원
#
#
# - 관련 문서 2:
# ...
